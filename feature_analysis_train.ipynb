# %%
import os
import pandas as pd

file_path = "./inputs/"
files = os.listdir(file_path)
files
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']

# %%
# Load the data
df = pd.read_csv(file_path + files[2]).set_index("id")
df
# Out:
#         Temparature  Humidity  Moisture Soil Type    Crop Type  Nitrogen  \
# id
# 0                37        70        36    Clayey    Sugarcane        36
# 1                27        69        65     Sandy      Millets        30
# 2                29        63        32     Sandy      Millets        24
# 3                35        62        54     Sandy       Barley        39
# 4                35        58        43       Red        Paddy        37
# ...             ...       ...       ...       ...          ...       ...
# 749995           25        69        30    Clayey        Maize         8
# 749996           37        64        58     Loamy    Sugarcane        38
# 749997           35        68        59     Sandy  Ground Nuts         6
# 749998           31        68        29       Red       Cotton         9
# 749999           33        55        29     Loamy       Cotton         4
#
#         Potassium  Phosphorous Fertilizer Name
# id
# ...

# %%
df.describe()
# Out:
#          Temparature       Humidity       Moisture       Nitrogen  \
# count  750000.000000  750000.000000  750000.000000  750000.000000
# mean       31.503565      61.038912      45.184147      23.093808
# std         4.025574       6.647695      11.794594      11.216125
# min        25.000000      50.000000      25.000000       4.000000
# 25%        28.000000      55.000000      35.000000      13.000000
# 50%        32.000000      61.000000      45.000000      23.000000
# 75%        35.000000      67.000000      55.000000      33.000000
# max        38.000000      72.000000      65.000000      42.000000
#
#            Potassium    Phosphorous
# count  750000.000000  750000.000000
# mean        9.478296      21.073227
# std         5.765622      12.346831
# min         0.000000       0.000000
# 25%         4.000000      10.000000
# 50%         9.000000      21.000000
# 75%        14.000000      32.000000
# max        19.000000      42.000000

# %%
# Missing Values?
df.isnull().sum()
# Out:
# Temparature        0
# Humidity           0
# Moisture           0
# Soil Type          0
# Crop Type          0
# Nitrogen           0
# Potassium          0
# Phosphorous        0
# Fertilizer Name    0
# dtype: int64

# %%
# Determine the categorical and non-categorical columns
categories = df.select_dtypes(include=object).columns[:-1]
non_categories = df.select_dtypes(include=["number"]).columns

display(categories)
display(non_categories)
# Out:
# Index(['Soil Type', 'Crop Type'], dtype='object')
# Index(['Temparature', 'Humidity', 'Moisture', 'Nitrogen', 'Potassium',
#        'Phosphorous'],
#       dtype='object')

# %%
# Unique in the target column
df["Fertilizer Name"].unique()
# Out:
# array(['28-28', '17-17-17', '10-26-26', 'DAP', '20-20', '14-35-14',
#        'Urea'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for column in non_categories:
    plt.figure(figsize=(15, 8))
    plt.subplot(1, 2, 1)
    sns.boxplot(data=df, y=column, )
    plt.subplot(1, 2, 2)
    sns.histplot(data=df, x=column, kde=False)
    plt.show()

# %%
for column in categories:
    plt.figure(figsize=(15, 8))
    sns.countplot(data=df, x=column, order=df[column].value_counts().index)
    plt.title(f'Countplot of {column}')
    plt.xticks(rotation=45)
    plt.show()

# %%
from sklearn.decomposition import
# Out:
# Error in callback <function flush_figures at 0x00000287395F1300> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\DataspellProjects\Kaggle-Optimal-Fertilizer-Prediction\venv\Lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~\DataspellProjects\Kaggle-Optimal-Fertilizer-Prediction\venv\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
# ...
